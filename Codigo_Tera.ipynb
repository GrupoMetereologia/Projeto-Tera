# %% [markdown]
# <a href="https://colab.research.google.com/github/GrupoMetereologia/Projeto-Tera/blob/main/Codigo_Tera.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df_meteo=pd.read_csv('/content/open-meteo-19.20S40.90W473m.csv')
df_pesca = pd.read_csv("/content/PESCA_2013_2023.csv", encoding="ISO-8859-1", sep = ';')

# %%
df_pesca
# Out:
#       Ano  Mês kg no Período valor estimado no período
# 0    2013    1     967767,94                5356381,85
# 1    2013    2    3952995,73               13453475,25
# 2    2013    3    3821078,89               11022569,29
# 3    2013    4    2779486,42                8767909,04
# 4    2013    5    2425166,00                 6665852,5
# ..    ...  ...           ...                       ...
# 122  2023    3     572671,44                5440246,58
# 123  2023    4     503425,49                5610516,63
# 124  2023    5    1301817,17                14891870,4
# 125  2023    6     818455,15               10015305,05
# 126  2023    7    1070543,75               15700066,27
#
# [127 rows x 4 columns]

# %%
df_meteo
# Out:
#                latitude            longitude  elevation  utc_offset_seconds  \
# 0            -19.199997           -40.899994      473.0                 0.0
# 1                  time  temperature_2m (°C)        NaN                 NaN
# 2      2013-01-01T00:00                 23.2        NaN                 NaN
# 3      2013-01-01T01:00                 22.4        NaN                 NaN
# 4      2013-01-01T02:00                 21.8        NaN                 NaN
# ...                 ...                  ...        ...                 ...
# 92733  2023-07-31T19:00                 22.4        NaN                 NaN
# 92734  2023-07-31T20:00                 22.0        NaN                 NaN
# 92735  2023-07-31T21:00                 21.5        NaN                 NaN
# 92736  2023-07-31T22:00                 20.1        NaN                 NaN
# 92737  2023-07-31T23:00                 18.9        NaN                 NaN
#
#       timezone timezone_abbreviation
# ...

# %%
df_meteo.drop(0)
# Out:
#                latitude            longitude  elevation  utc_offset_seconds  \
# 1                  time  temperature_2m (°C)        NaN                 NaN
# 2      2013-01-01T00:00                 23.2        NaN                 NaN
# 3      2013-01-01T01:00                 22.4        NaN                 NaN
# 4      2013-01-01T02:00                 21.8        NaN                 NaN
# 5      2013-01-01T03:00                 21.6        NaN                 NaN
# ...                 ...                  ...        ...                 ...
# 92733  2023-07-31T19:00                 22.4        NaN                 NaN
# 92734  2023-07-31T20:00                 22.0        NaN                 NaN
# 92735  2023-07-31T21:00                 21.5        NaN                 NaN
# 92736  2023-07-31T22:00                 20.1        NaN                 NaN
# 92737  2023-07-31T23:00                 18.9        NaN                 NaN
#
#       timezone timezone_abbreviation
# ...

# %%
df_meteo=df_meteo.iloc[:,:2]
df_meteo
# Out:
#                latitude            longitude
# 0            -19.199997           -40.899994
# 1                  time  temperature_2m (°C)
# 2      2013-01-01T00:00                 23.2
# 3      2013-01-01T01:00                 22.4
# 4      2013-01-01T02:00                 21.8
# ...                 ...                  ...
# 92733  2023-07-31T19:00                 22.4
# 92734  2023-07-31T20:00                 22.0
# 92735  2023-07-31T21:00                 21.5
# 92736  2023-07-31T22:00                 20.1
# 92737  2023-07-31T23:00                 18.9
#
# [92738 rows x 2 columns]
